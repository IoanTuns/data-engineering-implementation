# %%
dbutils.library.restartPython()

# %%
from datetime import datetime
import pandas as pd

# %%
import sys

sys.path.append("../../src")
from dataDP.utils.logger import logger
from dataDP.ingest.get_taxi import ingest_ny_taxi_data
from dataDP.stg.create_stg_tables import populate_stg_tables_from_storage

# %%
# %sh
ping google.com

# %% [markdown]
# # Serverless computes of Databricks free have no internet access.
# **Use localy src/dataDP/ingest/upload_to_databricks.py**

# %%
populate_stg_tables_from_storage(("workspace.stg.taxi_zone_lookup",), file_format="csv", csv_header = True)
